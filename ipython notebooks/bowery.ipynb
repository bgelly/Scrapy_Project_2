# %%
import numpy as np
import pandas as pd
from datetime import datetime
import time

# %%
bowery = pd.read_csv('bowery/bowery.csv')

# %%
import re

# strip white space from columns
bowery.location = bowery.location.str.strip()
bowery.date = bowery.date.str.strip()
bowery.headline_artist_name = bowery.headline_artist_name.str.strip()
bowery.other_artists_name = bowery.other_artists_name.str.strip()
bowery.price = bowery.price.str.strip()
bowery.time = bowery.time.str.strip()

# %%
# split state and city, drop location
bowery['city'], bowery['state'] = bowery['location'].str.split(',', 1).str
bowery = bowery.drop(['location'], 1)

# split day of week and date, drop date
bowery['week_day'], bowery['date'] = bowery['date'].str.split(',', 1).str

# split doors time and show time, drop time
bowery['doors_time'], bowery['show_time'] = bowery['time'].str.split(',', 1).str
bowery = bowery.drop(['time'], 1)

# %%
# clean door_time and show_time

def time(x):
    clean_time = []
    for i in x:
        try:
            m = re.search("\d+:\d+ [PA][M]", i)
            clean_time.append(m.group(0))
        except:
            clean_time.append(None)
    return clean_time

# %%
bowery.doors_time = time(bowery.doors_time)

# %%
bowery.show_time = time(bowery.show_time)

# %%
# change button from "Buy Now" to "On_Sale"
bowery.button[bowery.button == "Buy Tickets"] = "On_Sale"

# %%
# clean adv price

def price(x):
    clean_price = []
    for i in x:
        if re.search("(Adv:) \$\d+\.\d+.\-.\$\d+\.\d+", i) is not None:
            m = re.search("(Adv:) \$\d+\.\d+.\-.\$\d+\.\d+", i)
            clean_price.append(m.group(0))
            
        elif re.search("(Adv:) \$\d+\.\d+", i) is not None:
            m = re.search("(Adv:) \$\d+\.\d+", i)
            clean_price.append(m.group(0))
            
        else:
            clean_price.append("NA")
    return clean_price

# %%
bowery["adv_price"] = price(bowery.price)

# %%
#clean door price

def door_price(x):
    clean_price = []
    for i in x:
        if re.search("(Door:) \$\d+\.\d+.\-.\$\d+\.\d+", i) is not None:
            m = re.search("(Door:) \$\d+\.\d+.\-.\$\d+\.\d+", i)
            clean_price.append(m.group(0))
            
        elif re.search("(Door:) \$\d+\.\d+", i) is not None:
            m = re.search("(Door:) \$\d+\.\d+", i)
            clean_price.append(m.group(0))
            
        else:
            clean_price.append("NA")
    return clean_price

# %%
bowery["door_price"] = door_price(bowery.price)

# %%
bowery = bowery.drop(['price'], 1)

# %%
# drop rows where adv_price and door_price is NA
bowery = bowery[(bowery.adv_price != "NA") | (bowery.door_price != "NA")]

# %%
# clean adv_price
def adv_price_split(x):
    clean_price = []
    for i in x:
        if re.search("\d+\.\d+ \- \$\d+\.\d+", i) is not None:
            m = re.search("\d+\.\d+ \- \$\d+\.\d+", i)
            clean_price.append(m.group(0))
            
        elif re.search("\d+\.\d+", i) is not None:
            m = re.search("\d+\.\d+", i)
            clean_price.append(m.group(0))
            
        else:
            clean_price.append("NA")
    return clean_price

# %%
bowery["adv_price"] = adv_price_split(bowery.adv_price)

# %%
# split adv high price and low price
bowery['adv_price_low'], bowery['adv_price_high'] = bowery['adv_price'].str.split(' - ', 1).str

# %%
bowery = bowery.drop(['adv_price'], 1)

# %%
# remove dollar sign from adv_price_high
def rem_dollar(x):
    clean_dollar = []
    for i in x:
        try:
            m = re.search("\d+\.\d+", i)
            clean_dollar.append(m.group(0))
        except:
            clean_dollar.append("NA")
    return clean_dollar

# %%
bowery.adv_price_high = rem_dollar(bowery.adv_price_high)

# %%
def clean_door(x):
    clean_door = []
    for i in x:
        try:
            m = re.search("\d+\.\d+", i)
            clean_door.append(m.group(0))
        except:
            clean_door.append("NA")
    return clean_door

# %%
bowery.door_price = clean_door(bowery.door_price)

# %%
# prices to numeric
bowery.door_price = bowery.door_price.apply(pd.to_numeric, errors='coerce')
bowery.adv_price_high = bowery.adv_price_high.apply(pd.to_numeric, errors='coerce')
bowery.adv_price_low = bowery.adv_price_low.apply(pd.to_numeric, errors='coerce')

# %%
# create price range column
bowery['adv_price_range'] = bowery.adv_price_high - bowery.adv_price_low

# %%
# take only rows where adv price range is less than 5
bowery = bowery[(np.isnan(bowery.adv_price_range)) | (bowery.adv_price_range<5)]

# %%
# add date time column - show time
bowery['date_time'] = bowery.date + " " + bowery.show_time

# %%
from dateutil.parser import parse
def parse_time(x):
    empty_list = []
    for i in x:
        #parse(i)
        empty_list.append(parse(i))
    return empty_list

# %%
# parse date_time column and date column
bowery.date_time = parse_time(bowery.date_time)
bowery.date = parse_time(bowery.date)

# %%
group = bowery.groupby('button')['button']
group.size()

# drop where button == cancelled, coming soon, on sale soon, postponed

bowery = bowery[(bowery.button == 'On_Sale') | (bowery.button == 'Sold Out')]

# %%
# create days_from_scrape_to_show column
bowery['scrape_day'] = parse("05/12/18")
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
bowery['days_scrape_to_show'] = bowery.date - bowery.scrape_day
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# make headline artists more searchable

def clean_headliner(x):
    clean_headliner= []
    for i in x:
        if re.search('\(', i) is not None:
            clean_headliner.append(re.sub('\(.*?\)', '', i).strip())
            
        elif re.search('(?<=: ).*$', i) is not None:
            m = re.search('(?<=: ).*$', i)
            clean_headliner.append(m.group(0))
            
        elif re.search('.+?(?= -)', i) is not None:
            m = re.search('.+?(?= -)', i)
            clean_headliner.append(m.group(0))
            
        else:
            clean_headliner.append(i)
    return clean_headliner

# %%
bowery.headline_artist_name = clean_headliner(bowery.headline_artist_name)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
# split headliners
bowery['headliner1'], bowery['headliner2'] = bowery['headline_artist_name'].str.split("[,\+/]+", 1).str
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#drop festival of disruption
bowery = bowery[bowery.headliner1 != "Festival of Disruption"]

# %%
# clean other artists
def clean_other_artists(x):
    clean_other_artists = []
    for i in x:
        if i == np.nan:
            clean_other_artists.append(i)
        
        elif re.search('(with special guests)', str(i)) is not None:
            m = re.search('(?<=(with )).*$', i)
            clean_other_artists.append(m.group(0))
            
        elif re.search('(with)', str(i)) is not None:
            m = re.search('(?<=(with )).*$', i)
            clean_other_artists.append(m.group(0))
            
        elif re.search('\(', str(i)) is not None:
            clean_other_artists.append(re.sub('\(.*?\)', '', i).strip())
        
        else:
            clean_other_artists.append(i)
    return clean_other_artists

# %%
bowery.other_artists_name = clean_other_artists(bowery.other_artists_name)

# %%
# split other artists
bowery['other_artists1'], bowery['other_artists2'] = bowery['other_artists_name'].str.split("[,\+/]+", 1).str

# %%
# drop third or more other artists
def clean_other_artists2(x):
    clean_other_artists= []
    for i in x:
        if re.search(',', str(i)) is not None:
            clean_other_artists.append(re.sub('(?=,).*$', '', i).strip())
        else:
            clean_other_artists.append(i)
    return clean_other_artists

# %%
bowery.other_artists2 = clean_other_artists2(bowery.other_artists2)

# %%
headliners1 = bowery.headliner1

# %%
def lstrip(x):
    empty_list = []
    for i in x:
        if type(i) == float:
            empty_list.append(i)
        else:
            #i.lstrip()
            empty_list.append(i.lstrip())
            
    return empty_list

# %%
# strip extra starting spaces
bowery.headliner2 = lstrip(bowery.headliner2)
bowery.other_artists1 = lstrip(bowery.other_artists1)
bowery.other_artists2 = lstrip(bowery.other_artists2)

# %%
headliners2 = bowery.headliner2
others1 = bowery.other_artists1
others2 = bowery.other_artists2

# %store headliners2
# %store others1
# %store others2
# Out:
# Stored 'headliners2' (Series)
# Stored 'others1' (Series)
# Stored 'others2' (Series)

# %%
# %store -r headliners1_df
# %store -r headliners2_df
# %store -r others1_df
# %store -r others2_df

# %%
# rename artist_name
headliners2_df.rename(columns={'artist_name':'artist_name2'}, inplace=True)
others1_df.rename(columns={'artist_name':'other_artist_name1'}, inplace=True)
others2_df.rename(columns={'artist_name':'other_artist_name2'}, inplace=True)

# %%
# rename other dup cols - artist pop
headliners2_df.rename(columns={'artist_popularity':'artist2_popularity'}, inplace=True)
others1_df.rename(columns={'artist_popularity':'artist_popularityO1'}, inplace=True)
others2_df.rename(columns={'artist_popularity':'artist_popularityO2'}, inplace=True)

# %%
# rename other dup cols - artist fols
headliners2_df.rename(columns={'artist_followers':'artist2_followers'}, inplace=True)
others1_df.rename(columns={'artist_followers':'artist_followersO1'}, inplace=True)
others2_df.rename(columns={'artist_followers':'artist_followersO2'}, inplace=True)

# %%
# rename other dup cols - artist gen
headliners2_df.rename(columns={'artist_genres':'artist2_genres'}, inplace=True)
others1_df.rename(columns={'artist_genres':'artist_genresO1'}, inplace=True)
others2_df.rename(columns={'artist_genres':'artist_genresO2'}, inplace=True)

# %%
bowery = bowery.reset_index()
bowery = bowery.drop(['index'], 1)

# %%
bowery = pd.concat([bowery, headliners1_df, headliners2_df, others1_df, others2_df], axis=1)

# %%
# drop unessential cols and rows where artist_name is None - create boweryWorking
# drop doors_time, show_time, adv_price_range, headline_artist_name, other_artists_name
# drop date_time, scrape_day, headliner1, headliner2, other_artists1, other_artists2
# artist2_genres, artist_genresO1, artist_genresO2

# %%
boweryWorking = bowery.drop(['doors_time', 'show_time', 'headline_artist_name', 
                             'other_artists_name','show_time', 'adv_price_range',
                             'date_time', 'scrape_day','headliner1','headliner2',
                             'other_artists1','other_artists2','artist2_genres','artist_genresO1','artist_genresO2'], axis=1, inplace=False)

# %%
# drop rows where artist_name is null
boweryWorking = boweryWorking[boweryWorking.artist_name.notnull()]

# %%
group = boweryWorking.groupby('venue')['venue']
showsPerVenue = group.size()

# %%
# choose venues to scrape

#Notes:
# drop venues with less than 4 shows

# fete music hall combine ballroom and lounge
# royale to royale boston

# saturn is the one in birmingham, AL
# the national is in richmond, VA
# the sinclair is in cambridge, MA
showsPerVenue[showsPerVenue>3]
# Out:
# venue
# Aisle 5                        5
# Brooklyn Steel                43
# Fête Music Hall - Ballroom     5
# Fête Music Hall - Lounge       4
# Gasa Gasa                     17
# Great Scott                   50
# Music Hall of Williamsburg    38
# Rams Head Live!               22
# Rough Trade NYC               44
# Royale                        19
# Saturn                        27
# Starland Ballroom              6
# Terminal 5                     7
# Terminal West                  9
# The EARL                       6
# The National                  31
# The NorVa                     28
# The Sinclair                  55
# Underground Arts              14
# Variety Playhouse              7
# Name: venue, dtype: int64

# %%
boweryWorking
# Out:
#        button       date                       venue          city state  \
# 0     On_Sale 2018-11-11                   Gasa Gasa   New Orleans    LA
# 1     On_Sale 2018-11-12            Underground Arts  Philadelphia    PA
# 2     On_Sale 2018-11-14                The National      Richmond    VA
# 3     On_Sale 2018-11-15                   The NorVa       Norfolk    VA
# 4     On_Sale 2018-11-23                      Royale        Boston    MA
# 5     On_Sale 2018-11-30            Electric Factory  Philadelphia    PA
# 6     On_Sale 2018-12-08             Rough Trade NYC      Brooklyn    NY
# 7     On_Sale 2018-12-11                 Great Scott       Allston    MA
# 8     On_Sale 2018-12-26                The National      Richmond    VA
# 9    Sold Out 2018-12-27  Music Hall of Williamsburg      Brooklyn    NY
# 10    On_Sale 2018-12-28                   The NorVa       Norfolk    VA
# 11   Sold Out 2018-12-28  Music Hall of Williamsburg      Brooklyn    NY
# 12   Sold Out 2018-12-29  Music Hall of Williamsburg      Brooklyn    NY
# 13    On_Sale 2018-12-30  Music Hall of Williamsburg      Brooklyn    NY
# 14    On_Sale 2019-03-29              Brooklyn Steel      Brooklyn    NY
# 15    On_Sale 2019-03-30              Brooklyn Steel      Brooklyn    NY
# 16    On_Sale 2018-10-21            Underground Arts  Philadelphia    PA
# 17    On_Sale 2018-10-21                 Great Scott       Allston    MA
# 19    On_Sale 2018-10-22             Rough Trade NYC      Brooklyn    NY
# 20    On_Sale 2018-10-23                      Saturn    Birmingham    AL
# 21    On_Sale 2018-10-25               Terminal West       Atlanta    GA
# 22    On_Sale 2018-10-26             Rams Head Live!     Baltimore    MD
# 23    On_Sale 2018-10-27           Starland Ballroom    Sayreville    NJ
# 24    On_Sale 2018-10-27                   Palladium     Worcester    MA
# 25    On_Sale 2018-10-27                  Terminal 5      New York    NY
# 26    On_Sale 2018-10-27  Music Hall of Williamsburg      Brooklyn    NY
# 27    On_Sale 2018-10-06                      Royale        Boston    MA
# 28    On_Sale 2018-10-06                  Terminal 5      New York    NY
# 29    On_Sale 2018-10-28                      Royale        Boston    MA
# 30    On_Sale 2018-10-29                The Sinclair     Cambridge    MA
# ..        ...        ...                         ...           ...   ...
# 494   On_Sale 2018-05-17           Variety Playhouse       Atlanta    GA
# 495   On_Sale 2018-05-17                The Sinclair     Cambridge    MA
# 497   On_Sale 2018-05-17             Rough Trade NYC      Brooklyn    NY
# 498   On_Sale 2018-05-17  Music Hall of Williamsburg      Brooklyn    NY
# 500   On_Sale 2018-05-18                      Royale        Boston    MA
# 501   On_Sale 2018-05-18             Rams Head Live!     Baltimore    MD
# 502  Sold Out 2018-05-18                    The Loft       Atlanta    GA
# 503   On_Sale 2018-05-18                   Gasa Gasa   New Orleans    LA
# 505  Sold Out 2018-05-18           Variety Playhouse       Atlanta    GA
# 506   On_Sale 2018-05-18  Music Hall of Williamsburg      Brooklyn    NY
# 507   On_Sale 2018-05-18               Terminal West       Atlanta    GA
# 508   On_Sale 2018-05-18                The Sinclair     Cambridge    MA
# 511   On_Sale 2018-05-18                      Saturn    Birmingham    AL
# 513   On_Sale 2018-05-19                      Royale        Boston    MA
# 514   On_Sale 2018-05-19                   The NorVa       Norfolk    VA
# 518   On_Sale 2018-05-19           Variety Playhouse       Atlanta    GA
# 519  Sold Out 2018-05-19  Music Hall of Williamsburg      Brooklyn    NY
# 520   On_Sale 2018-05-19                 Great Scott       Allston    MA
# 521   On_Sale 2018-05-19                      Saturn    Birmingham    AL
# 523   On_Sale 2018-05-20                   The NorVa       Norfolk    VA
# 524  Sold Out 2018-05-20  Music Hall of Williamsburg      Brooklyn    NY
# 526   On_Sale 2018-05-20                      Royale        Boston    MA
# 527   On_Sale 2018-05-20             Rough Trade NYC      Brooklyn    NY
# 528  Sold Out 2018-05-20               Terminal West       Atlanta    GA
# 529   On_Sale 2018-05-20                 Great Scott       Allston    MA
# 531   On_Sale 2018-05-21                   The NorVa       Norfolk    VA
# 532   On_Sale 2018-05-21  Music Hall of Williamsburg      Brooklyn    NY
# 533   On_Sale 2018-05-21                      Saturn    Birmingham    AL
# 534  Sold Out 2018-05-21             Rough Trade NYC      Brooklyn    NY
# 535   On_Sale 2018-05-21                 Great Scott       Allston    MA
#
#     week_day  door_price  adv_price_low  adv_price_high days_scrape_to_show  \
# 0        Sun       12.00           8.00             NaN            182 days
# 1        Mon         NaN          22.00            25.0            183 days
# 2        Wed       43.00          39.50            43.5            185 days
# 3        Thu       23.00          20.50             NaN            186 days
# 4        Fri       30.00          27.00            30.0            194 days
# 5        Fri         NaN          27.50            30.0            201 days
# 6        Sat       18.00          15.00             NaN            209 days
# 7        Tue       12.00          12.00             NaN            212 days
# 8        Wed       23.00          20.00             NaN            227 days
# 9        Thu       35.00          35.00             NaN            228 days
# 10       Fri       23.00          20.00             NaN            229 days
# 11       Fri       35.00          35.00             NaN            229 days
# 12       Sat       35.00          35.00             NaN            230 days
# 13       Sun       35.00          35.00             NaN            231 days
# 14       Fri       45.00          35.00             NaN            320 days
# 15       Sat       45.00          35.00             NaN            321 days
# 16       Sun         NaN          15.00            18.0            161 days
# 17       Sun       15.00          12.00            15.0            161 days
# 19       Mon         NaN          15.00             NaN            162 days
# 20       Tue       12.00            NaN             NaN            163 days
# 21       Thu       16.00            NaN             NaN            165 days
# 22       Fri         NaN          27.50             NaN            166 days
# 23       Sat       28.00          25.00             NaN            167 days
# 24       Sat       35.00          35.00             NaN            167 days
# 25       Sat         NaN          30.00             NaN            167 days
# 26       Sat         NaN          30.00             NaN            167 days
# 27       Sat       20.00          18.00            20.0            146 days
# 28       Sat         NaN          35.00             NaN            146 days
# 29       Sun       29.00          26.50            29.0            168 days
# 30       Mon       17.00          15.00            17.0            169 days
# ..       ...         ...            ...             ...                 ...
# 494      Thu       21.00            NaN             NaN              4 days
# 495      Thu       29.50          29.50             NaN              4 days
# 497      Thu         NaN          15.00             NaN              4 days
# 498      Thu       18.00          15.00             NaN              4 days
# 500      Fri       22.00          20.00            22.0              5 days
# 501      Fri         NaN          25.00             NaN              5 days
# 502      Fri       20.00            NaN             NaN              5 days
# 503      Fri       12.00          10.00             NaN              5 days
# 505      Fri       17.00            NaN             NaN              5 days
# 506      Fri       20.00          18.00             NaN              5 days
# 507      Fri       30.00            NaN             NaN              5 days
# 508      Fri       18.00          15.00            18.0              5 days
# 511      Fri       20.00            NaN             NaN              5 days
# 513      Sat       25.00          23.00            25.0              6 days
# 514      Sat       12.00          10.00             NaN              6 days
# 518      Sat       26.00            NaN             NaN              6 days
# 519      Sat       32.75          32.75             NaN              6 days
# 520      Sat       15.00          12.00            15.0              6 days
# 521      Sat       15.00            NaN             NaN              6 days
# 523      Sun       29.00          23.50             NaN              7 days
# 524      Sun       35.00          35.00             NaN              7 days
# 526      Sun       25.00          25.00             NaN              7 days
# 527      Sun         NaN          20.00             NaN              7 days
# 528      Sun       25.00            NaN             NaN              7 days
# 529      Sun       15.00          12.00            15.0              7 days
# 531      Mon       23.00          19.50             NaN              8 days
# 532      Mon         NaN          35.00             NaN              8 days
# 533      Mon        7.00            NaN             NaN              8 days
# 534      Mon       20.00          15.00             NaN              8 days
# 535      Mon       15.00          13.00            15.0              8 days
#
#             ...          artist_popularity artist2_followers artist_name2  \
# 0           ...                       33.0               nan         None
# 1           ...                       57.0               nan         None
# 2           ...                       56.0               nan         None
# 3           ...                       59.0               nan         None
# 4           ...                       59.0               nan         None
# 5           ...                       55.0               nan         None
# 6           ...                       58.0               nan         None
# 7           ...                       38.0               nan         None
# 8           ...                        6.0               nan         None
# 9           ...                       47.0               nan         None
# 10          ...                        6.0               nan         None
# 11          ...                       47.0               nan         None
# 12          ...                       47.0               nan         None
# 13          ...                       47.0               nan         None
# 14          ...                       68.0               nan         None
# 15          ...                       68.0               nan         None
# 16          ...                       49.0               nan         None
# 17          ...                       38.0               nan         None
# 19          ...                       38.0               nan         None
# 20          ...                       47.0               nan         None
# 21          ...                       58.0               nan         None
# 22          ...                       56.0               nan         None
# 23          ...                       60.0               nan         None
# 24          ...                       56.0               nan         None
# 25          ...                       56.0               nan         None
# 26          ...                       44.0               nan         None
# 27          ...                       68.0               nan         None
# 28          ...                       77.0               nan         None
# 29          ...                       64.0               nan         None
# 30          ...                       48.0               nan         None
# ..          ...                        ...               ...          ...
# 494         ...                       47.0               nan         None
# 495         ...                       63.0               nan         None
# 497         ...                       75.0               nan         None
# 498         ...                       47.0               nan         None
# 500         ...                       16.0               nan         None
# 501         ...                       64.0               nan         None
# 502         ...                       57.0               nan         None
# 503         ...                       43.0               nan         None
# 505         ...                       46.0               nan         None
# 506         ...                       50.0               nan         None
# 507         ...                       50.0               nan         None
# 508         ...                       55.0               nan         None
# 511         ...                       56.0               nan         None
# 513         ...                       72.0               nan         None
# 514         ...                       12.0               nan         None
# 518         ...                       53.0               nan         None
# 519         ...                       61.0               nan         None
# 520         ...                       22.0               nan         None
# 521         ...                       42.0               nan         None
# 523         ...                       63.0               nan         None
# 524         ...                       63.0               nan         None
# 526         ...                       81.0               nan         None
# 527         ...                       36.0               nan         None
# 528         ...                       47.0               nan         None
# 529         ...                       56.0               nan         None
# 531         ...                       39.0               nan         None
# 532         ...                       63.0               nan         None
# 533         ...                        0.0               nan         None
# 534         ...                       72.0               nan         None
# 535         ...                       53.0               nan         None
#
#      artist2_popularity artist_followersO1             other_artist_name1  \
# 0                   NaN                nan                           None
# 1                   NaN                nan                           None
# 2                   NaN                nan                           None
# 3                   NaN              47765                Nick Waterhouse
# 4                   NaN              47765                Nick Waterhouse
# 5                   NaN                nan                           None
# 6                   NaN                nan                           None
# 7                   NaN                nan                           None
# 8                   NaN                nan                           None
# 9                   NaN                nan                           None
# 10                  NaN                nan                           None
# 11                  NaN                nan                           None
# 12                  NaN                nan                           None
# 13                  NaN                nan                           None
# 14                  NaN                nan                           None
# 15                  NaN                nan                           None
# 16                  NaN                nan                           None
# 17                  NaN                nan                           None
# 19                  NaN                nan                           None
# 20                  NaN               2399                 Kitten Forever
# 21                  NaN                940  The Range of Light Wilderness
# 22                  NaN                nan                           None
# 23                  NaN              26113                      Goatwhore
# 24                  NaN              32115           Teenage Bottlerocket
# 25                  NaN                nan                           None
# 26                  NaN                978            The Philistines Jr.
# 27                  NaN                nan                           None
# 28                  NaN                nan                           None
# 29                  NaN              41681                   Jamila Woods
# 30                  NaN                nan                           None
# ..                  ...                ...                            ...
# 494                 NaN                721                       Erin Rae
# 495                 NaN               1789                  inc. no world
# 497                 NaN                  4                    Leather Can
# 498                 NaN              14345                 Computer Magic
# 500                 NaN                nan                           None
# 501                 NaN              27301                           flor
# 502                 NaN                743                      Brik.Liam
# 503                 NaN  The Brenton Sound                           None
# 505                 NaN                nan                           None
# 506                 NaN               3282                      Cut Worms
# 507                 NaN                nan                           None
# 508                 NaN      The New Motif                           None
# 511                 NaN               1382                      Buzzy Lee
# 513                 NaN              18435                    Foreign Air
# 514                 NaN                nan                           None
# 518                 NaN              28738           My Brightest Diamond
# 519                 NaN              16515                      Palehound
# 520                 NaN                361                Obsidian Tongue
# 521                 NaN                nan                           None
# 523                 NaN              98019                        Bayside
# 524                 NaN               1789                  inc. no world
# 526                 NaN              36734                         88GLAM
# 527                 NaN              12648                  Kendra Morris
# 528                 NaN               2146                 Lunar Vacation
# 529                 NaN                nan                           None
# 531                 NaN                  0                        Folkjet
# 532                 NaN               1789                  inc. no world
# 533                 NaN                nan                           None
# 534                 NaN                nan                           None
# 535                 NaN              27713                     Beta Radio
#
#      artist_popularityO1 artist_followersO2            other_artist_name2  \
# 0                    NaN                NaN                          None
# 1                    NaN                NaN                          None
# 2                    NaN                NaN                          None
# 3                   65.0                NaN                          None
# 4                   65.0                NaN                          None
# 5                    NaN                NaN                          None
# 6                    NaN                NaN                          None
# 7                    NaN                NaN                          None
# 8                    NaN                NaN                          None
# 9                    NaN                NaN                          None
# 10                   NaN                NaN                          None
# 11                   NaN                NaN                          None
# 12                   NaN                NaN                          None
# 13                   NaN                NaN                          None
# 14                   NaN                NaN                          None
# 15                   NaN                NaN                          None
# 16                   NaN                NaN                          None
# 17                   NaN                NaN                          None
# 19                   NaN                NaN                          None
# 20                  25.0                NaN                          None
# 21                  15.0                NaN                          None
# 22                   NaN               1723                       Uncured
# 23                  36.0             423590                       Ruth B.
# 24                  49.0                NaN                          None
# 25                   NaN                NaN                          None
# 26                  10.0                NaN                          None
# 27                   NaN                NaN                          None
# 28                   NaN                NaN                          None
# 29                  54.0                NaN                          None
# 30                   NaN                NaN                          None
# ..                   ...                ...                           ...
# 494                 36.0                 28                 Samson Oxmoor
# 495                 17.0                NaN                          None
# 497                  0.0               2386                      gobbinjr
# 498                 36.0                NaN                          None
# 500                  NaN               8967                Flint Eastwood
# 501                 60.0                NaN                          None
# 502                 19.0                NaN                          None
# 503                  NaN                NaN                          None
# 505                  NaN                  7                       sasami.
# 506                 39.0                NaN                          None
# 507                  NaN                NaN                          None
# 508                  NaN                NaN                          None
# 511                 41.0                NaN                          None
# 513                 53.0                NaN                          None
# 514                  NaN                NaN                          None
# 518                 38.0                NaN                          None
# 519                 42.0               4610               Falls of Rauros
# 520                  3.0                NaN                          None
# 521                  NaN    plus DJ Easy Ed                          None
# 523                 54.0               2009  Starchild & The New Romantic
# 524                 17.0                NaN                          None
# 526                 63.0                NaN                          None
# 527                 45.0                NaN                          None
# 528                 33.0                NaN                          None
# 529                  NaN                NaN                          None
# 531                  0.0               2093                 The True Blue
# 532                 17.0                NaN                          None
# 533                  NaN                NaN                          None
# 534                  NaN                NaN                          None
# 535                 55.0                NaN                           NaN
#
#      artist_popularityO2
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                  24.0
# 23                  69.0
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# 30                   NaN
# ..                   ...
# 494                 41.0
# 495                  NaN
# 497                 26.0
# 498                  NaN
# 500                 40.0
# 501                  NaN
# 502                  NaN
# 503                  NaN
# 505                  0.0
# 506                  NaN
# 507                  NaN
# 508                  NaN
# 511                  NaN
# 513                  NaN
# 514                  NaN
# 518                  NaN
# 519                 18.0
# 520                  NaN
# 521                  NaN
# 523                 29.0
# 524                  NaN
# 526                  NaN
# 527                  NaN
# 528                  NaN
# 529                  NaN
# 531                 35.0
# 532                  NaN
# 533                  NaN
# 534                  NaN
# 535                  NaN
#
# [465 rows x 23 columns]

# %%
# %store boweryWorking
# Out:
# Stored 'boweryWorking' (DataFrame)
